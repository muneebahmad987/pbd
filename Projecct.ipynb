# %%
#%pip install nltk                 ]
#nltk.download('stopwords')        ]
#nltk.download('punkt')            ]--->We will only use these commands to download these libraries only once
#download('stopwords')             ]
#nltk.download('wordnet')          ]
import nltk
import os
folderpath = r"C:\Users\\OneDrive\Desktop\Articles3"  #Path of the file
filepaths  = [os.path.join(folderpath, name) for name in os.listdir(folderpath)]
files = []

for path in filepaths:
    with open(path, 'r', encoding="ISO-8859-1") as f:
        file = f.readlines()
        files.append(file)

# %%
files
# Out:
# [['[[Allen Ginsberg]]\n',
#   '\n',
#   'Irwin Allen Ginsberg (; June 3, 1926 â\x80\x93 April 5, 1997) was an American poet and one of the leading figures of both the Beat Generation of the 1950s and the counterculture that soon would follow. He vigorously opposed militarism, economic materialism and sexual repression. Ginsberg is best known for his epic poem "Howl", in which he denounced what he saw as the destructive forces of capitalism and conformity in the United States. Ginsberg, Allen (2000), Deliberate Prose: Selected Essays 1952â\x80\x931995. Foreword by Edward Sanders. New York: HarperCollinsPublishers, pp. xxâ\x80\x93xxi. de Grazia, Edward. (1992) . New York: Random House, pp. 330â\x80\x9331. http://www.pbs.org/wnet/americanmasters/episodes/allen-ginsberg/about-allen-ginsberg/613/ \n',
#   '\n',
# ...

# %%
FilesSize=len(files)
print(FilesSize)
# Out:
# 1

# %%
InStringForm = ' '.join(map(str, files)) 
print(InStringForm)
# Out:
# ['[[Allen Ginsberg]]\n', '\n', 'Irwin Allen Ginsberg (; June 3, 1926 â\x80\x93 April 5, 1997) was an American poet and one of the leading figures of both the Beat Generation of the 1950s and the counterculture that soon would follow. He vigorously opposed militarism, economic materialism and sexual repression. Ginsberg is best known for his epic poem "Howl", in which he denounced what he saw as the destructive forces of capitalism and conformity in the United States. Ginsberg, Allen (2000), Deliberate Prose: Selected Essays 1952â\x80\x931995. Foreword by Edward Sanders. New York: HarperCollinsPublishers, pp. xxâ\x80\x93xxi. de Grazia, Edward. (1992) . New York: Random House, pp. 330â\x80\x9331. http://www.pbs.org/wnet/americanmasters/episodes/allen-ginsberg/about-allen-ginsberg/613/ \n', '\n', 'In 1957, "Howl" attracted widespread publicity when it became the subject of an obscenity trial, as it depicted heterosexual and homosexual sex see Ginsberg, "Howl" pp. 13â\x80\x9315. at a tim
# ...

# %%
InStringForm
# Out:
# '[\'[[Allen Ginsberg]]\\n\', \'\\n\', \'Irwin Allen Ginsberg (; June 3, 1926 â\\x80\\x93 April 5, 1997) was an American poet and one of the leading figures of both the Beat Generation of the 1950s and the counterculture that soon would follow. He vigorously opposed militarism, economic materialism and sexual repression. Ginsberg is best known for his epic poem "Howl", in which he denounced what he saw as the destructive forces of capitalism and conformity in the United States. Ginsberg, Allen (2000), Deliberate Prose: Selected Essays 1952â\\x80\\x931995. Foreword by Edward Sanders. New York: HarperCollinsPublishers, pp. xxâ\\x80\\x93xxi. de Grazia, Edward. (1992) . New York: Random House, pp. 330â\\x80\\x9331. http://www.pbs.org/wnet/americanmasters/episodes/allen-ginsberg/about-allen-ginsberg/613/ \\n\', \'\\n\', \'In 1957, "Howl" attracted widespread publicity when it became the subject of an obscenity trial, as it depicted heterosexual and homosexual sex see Ginsberg, "Howl" pp. 1
# ...

# %%
import nltk
from nltk.corpus import stopwords

from nltk.tokenize import word_tokenize

text_tokens = word_tokenize(InStringForm)

text_tokens
# Out:
# ['[',
#  "'",
#  '[',
#  '[',
#  'Allen',
#  'Ginsberg',
#  ']',
#  ']',
#  '\\n',
#  "'",
#  ',',
#  "'\\n",
#  "'",
#  ',',
#  "'Irwin",
#  'Allen',
#  'Ginsberg',
#  '(',
#  ';',
#  'June',
#  '3',
#  ',',
#  '1926',
#  'â\\x80\\x93',
#  'April',
#  '5',
#  ',',
#  '1997',
#  ')',
#  'was',
#  'an',
#  'American',
#  'poet',
#  'and',
#  'one',
#  'of',
#  'the',
#  'leading',
#  'figures',
#  'of',
#  'both',
#  'the',
#  'Beat',
#  'Generation',
#  'of',
#  'the',
#  '1950s',
#  'and',
#  'the',
#  'counterculture',
#  'that',
#  'soon',
#  'would',
#  'follow',
#  '.',
#  'He',
#  'vigorously',
#  'opposed',
#  'militarism',
#  ',',
#  'economic',
#  'materialism',
#  'and',
#  'sexual',
#  'repression',
#  '.',
#  'Ginsberg',
#  'is',
#  'best',
#  'known',
#  'for',
#  'his',
#  'epic',
#  'poem',
#  '``',
#  'Howl',
#  "''",
#  ',',
#  'in',
#  'which',
#  'he',
#  'denounced',
#  'what',
#  'he',
#  'saw',
#  'as',
#  'the',
#  'destructive',
#  'forces',
#  'of',
# ...

# %%
print(text_tokens)
# Out:
# ['[', "'", '[', '[', 'Allen', 'Ginsberg', ']', ']', '\\n', "'", ',', "'\\n", "'", ',', "'Irwin", 'Allen', 'Ginsberg', '(', ';', 'June', '3', ',', '1926', 'â\\x80\\x93', 'April', '5', ',', '1997', ')', 'was', 'an', 'American', 'poet', 'and', 'one', 'of', 'the', 'leading', 'figures', 'of', 'both', 'the', 'Beat', 'Generation', 'of', 'the', '1950s', 'and', 'the', 'counterculture', 'that', 'soon', 'would', 'follow', '.', 'He', 'vigorously', 'opposed', 'militarism', ',', 'economic', 'materialism', 'and', 'sexual', 'repression', '.', 'Ginsberg', 'is', 'best', 'known', 'for', 'his', 'epic', 'poem', '``', 'Howl', "''", ',', 'in', 'which', 'he', 'denounced', 'what', 'he', 'saw', 'as', 'the', 'destructive', 'forces', 'of', 'capitalism', 'and', 'conformity', 'in', 'the', 'United', 'States', '.', 'Ginsberg', ',', 'Allen', '(', '2000', ')', ',', 'Deliberate', 'Prose', ':', 'Selected', 'Essays', '1952â\\x80\\x931995', '.', 'Foreword', 'by', 'Edward', 'Sanders', '.', 'New', 'York', ':', 'HarperColli
# ...

# %%
token = [word for word in text_tokens if not word in stopwords.words()]

token
# Out:
# ['[',
#  "'",
#  '[',
#  '[',
#  'Allen',
#  'Ginsberg',
#  ']',
#  ']',
#  '\\n',
#  "'",
#  ',',
#  "'\\n",
#  "'",
#  ',',
#  "'Irwin",
#  'Allen',
#  'Ginsberg',
#  '(',
#  ';',
#  'June',
#  '3',
#  ',',
#  '1926',
#  'â\\x80\\x93',
#  'April',
#  '5',
#  ',',
#  '1997',
#  ')',
#  'American',
#  'poet',
#  'leading',
#  'figures',
#  'Beat',
#  'Generation',
#  '1950s',
#  'counterculture',
#  'soon',
#  'would',
#  'follow',
#  '.',
#  'He',
#  'vigorously',
#  'opposed',
#  'militarism',
#  ',',
#  'economic',
#  'materialism',
#  'sexual',
#  'repression',
#  '.',
#  'Ginsberg',
#  'best',
#  'known',
#  'epic',
#  'poem',
#  '``',
#  'Howl',
#  "''",
#  ',',
#  'denounced',
#  'saw',
#  'destructive',
#  'forces',
#  'capitalism',
#  'conformity',
#  'United',
#  'States',
#  '.',
#  'Ginsberg',
#  ',',
#  'Allen',
#  '(',
#  '2000',
#  ')',
#  ',',
#  'Deliberate',
#  'Prose',
#  ':',
#  'Selected',
#  'Essays',
#  '1952â\\x80\\x931995',
#  '.',
#  'Foreword',
# ...

# %%
print(token)
# Out:
# ['[', "'", '[', '[', 'Allen', 'Ginsberg', ']', ']', '\\n', "'", ',', "'\\n", "'", ',', "'Irwin", 'Allen', 'Ginsberg', '(', ';', 'June', '3', ',', '1926', 'â\\x80\\x93', 'April', '5', ',', '1997', ')', 'American', 'poet', 'leading', 'figures', 'Beat', 'Generation', '1950s', 'counterculture', 'soon', 'would', 'follow', '.', 'He', 'vigorously', 'opposed', 'militarism', ',', 'economic', 'materialism', 'sexual', 'repression', '.', 'Ginsberg', 'best', 'known', 'epic', 'poem', '``', 'Howl', "''", ',', 'denounced', 'saw', 'destructive', 'forces', 'capitalism', 'conformity', 'United', 'States', '.', 'Ginsberg', ',', 'Allen', '(', '2000', ')', ',', 'Deliberate', 'Prose', ':', 'Selected', 'Essays', '1952â\\x80\\x931995', '.', 'Foreword', 'Edward', 'Sanders', '.', 'New', 'York', ':', 'HarperCollinsPublishers', ',', 'pp', '.', 'xxâ\\x80\\x93xxi', '.', 'Grazia', ',', 'Edward', '.', '(', '1992', ')', '.', 'New', 'York', ':', 'Random', 'House', ',', 'pp', '.', '330â\\x80\\x9331', '.', 'http', ':', '
# ...

# %%
#nltk.download('omw-1.4')
from nltk.stem import WordNetLemmatizer
lemmatizedText=WordNetLemmatizer()
lem=[]
for r in token:
    lem.append(lemmatizedText.lemmatize(r))
    
print (lemmatizedText.lemmatize('buildings'))
# Out:
# building

# %%
# Here We will be Removing all the special characters from the text after it has been tokenized
import re
updated=[]
updated=[re.sub('[^a-zA-Z0-9]+','',_) for _ in l]
updated #updated file
# Out:
# ['0',
#  '',
#  '',
#  '',
#  '',
#  'Anarchism',
#  '',
#  '',
#  'n',
#  '',
#  '',
#  'n',
#  '',
#  '',
#  'Anarchism',
#  'political',
#  'philosophy',
#  'advocate',
#  'stateless',
#  'society',
#  'often',
#  'defined',
#  'selfgoverned',
#  'voluntary',
#  'institution',
#  '',
#  '',
#  'ANARCHISM',
#  '',
#  'social',
#  'philosophy',
#  'reject',
#  'authoritarian',
#  'government',
#  'maintains',
#  'voluntary',
#  'institution',
#  'best',
#  'suited',
#  'express',
#  'man',
#  's',
#  'natural',
#  'social',
#  'tendency',
#  '',
#  '',
#  'George',
#  'Woodcock',
#  '',
#  '',
#  'Anarchism',
#  '',
#  'The',
#  'Encyclopedia',
#  'Philosophy',
#  '',
#  'In',
#  'society',
#  'developed',
#  'line',
#  '',
#  'voluntary',
#  'association',
#  'already',
#  'begin',
#  'cover',
#  'field',
#  'human',
#  'activity',
#  'would',
#  'still',
#  'greater',
#  'extension',
#  'substitute',
#  'state',
#  'function',
#  '',
#  '',
#  'Peter',
#  'Kropotkin',
#  '',
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
#import warnings
#from warnings import simplefilter
#simplefilter(action='ignore', category=FutureWarning)
vectorizer = TfidfVectorizer(stop_words='english') #Vactorizing
VectorizedValues = vectorizer.fit_transform(updated)

# %%
NumberOfClustersToBeFormed = 6
model = KMeans(n_clusters=k, init='k-means++', max_iter=100, n_init=1)
model.fit(VectorizedValues)
# Out:
# KMeans(max_iter=100, n_clusters=6, n_init=1)

# %%
print("Values of each And Every cluster")
order_centroids = model.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()
for i in range(k):
    print("Cluster %d:" % i),
    for ind in order_centroids[i, :10]:
        print(' %s' % terms[ind]),
# Out:
# Values of each And Every cluster
# Cluster 0:
#  political
#  zhuangzi
#  emir
#  element
#  elisa
#  elite
#  elizalde
#  eloquence
#  emerged
#  emerges
# Cluster 1:
#  word
#  zhuangzi
#  emir
#  element
#  elisa
#  elite
#  elizalde
#  eloquence
#  emerged
#  emerges
# Cluster 2:
#  anarchism
#  zhuangzi
#  emma
#  elite
#  elizalde
#  eloquence
#  emerged
#  emerges
#  emir
#  emperors
# Cluster 3:
#  libertarianism
#  zhuangzi
#  emir
#  element
#  elisa
#  elite
#  elizalde
#  eloquence
#  emerged
#  emerges
# Cluster 4:
#  anarchist
#  authority
#  state
#  proudhon
#  philosophy
#  society
#  press
#  social
#  government
#  use
# Cluster 5:
#  version
#  zhuangzi
#  emerges
#  elected
#  element
#  elisa
#  elite
#  elizalde
#  eloquence
#  emerged
